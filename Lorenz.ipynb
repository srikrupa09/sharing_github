# %% [markdown]
# # HEADER 1

# %% [markdown]
# ## HEADER 2

# %% [markdown]
# ### HEADER3

# %% [markdown]
# #### HEADER 4

# %% [markdown]
# ##### HEARDER 5

# %% [markdown]
# ###### HEADER 6

# %% [markdown]
# \*literal asterisks\*

# %% [markdown]
# | This | is   |
# |------|------|
# |   a  | table|

# %% [markdown]
# <img src="../images/python_logo.svg" />

# %% [markdown]
# **BOLD**

# %% [markdown]
# *ITALIC*

# %% [markdown]
# <FONT COLOR=BLUE>BLUE</FONT>

# %% [markdown]
# ***
